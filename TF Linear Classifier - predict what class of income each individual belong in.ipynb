# %% [markdown]
# # TensorFlow Linear Classifier

# %% [markdown]
# ## predict what class of income each individual belong in (>50k or <=50k)

# %%
#imports
import pandas as pd
import tensorflow as tf

#data
df = pd.read_csv('../Tensorflow-Bootcamp-master/02-TensorFlow-Basics/census_data.csv')
print(df.columns, '\n')
df['income_bracket'] = df['income_bracket'].apply(lambda x: 1 if x==' >50K' else 0)
assigned_workclass = tf.feature_column.categorical_column_with_hash_bucket('workclass',hash_bucket_size=1000)
assigned_education = tf.feature_column.categorical_column_with_hash_bucket('education',hash_bucket_size=1000)
assigned_marital_status = tf.feature_column.categorical_column_with_hash_bucket('marital_status',hash_bucket_size=1000)
assigned_occupation = tf.feature_column.categorical_column_with_hash_bucket('occupation',hash_bucket_size=1000)
assigned_relationship = tf.feature_column.categorical_column_with_hash_bucket('relationship',hash_bucket_size=1000)
assigned_race = tf.feature_column.categorical_column_with_hash_bucket('race',hash_bucket_size=1000)
assigned_gender = tf.feature_column.categorical_column_with_hash_bucket('gender',hash_bucket_size=1000)
assigned_native_country = tf.feature_column.categorical_column_with_hash_bucket('native_country',hash_bucket_size=1000)
age = tf.feature_column.numeric_column('age')
education_num = tf.feature_column.numeric_column('education_num')
capital_gain = tf.feature_column.numeric_column('capital_gain')
capital_loss = tf.feature_column.numeric_column('capital_loss')
hours_per_week = tf.feature_column.numeric_column('hours_per_week')

#split
X=df.drop('income_bracket',axis=1)
y=df['income_bracket']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

#model
feat_cols = [assigned_workclass,assigned_education,assigned_marital_status,assigned_occupation,assigned_relationship,
             assigned_race,assigned_gender,assigned_native_country,age,education_num,capital_gain,capital_loss,hours_per_week]
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=100, num_epochs=1000, shuffle=True)
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
model.train(input_fn=input_func, steps=5000)

#predication
pred_input_func=tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=100, num_epochs=1, shuffle=False)
results = list(model.predict(input_fn=pred_input_func))
predictions =[]
for x in results:
    predictions.append(x['class_ids'][0])
predictions

#evaluation
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print(classification_report(y_test,predictions), '\n')
print('accuracy_score: ', accuracy_score(y_test,predictions), '\n')
print(confusion_matrix(y_test,predictions))
# Out:
# Index(['age', 'workclass', 'education', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'gender', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'income_bracket'],
#       dtype='object')
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PERGO_~1\AppData\Local\Temp\tmp8cmlf2eg
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\PERGO_~1\\AppData\\Local\\Temp\\tmp8cmlf2eg', '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\PERGO_~1\AppData\Local\Temp\tmp8cmlf2eg\model.ckpt.
# INFO:tensorflow:step = 1, loss = 69.3147
# INFO:tensorflow:global_step/sec: 150.695
# INFO:tensorflow:step = 101, loss = 790.286 (0.669 sec)
# INFO:tensorflow:global_step/sec: 170.753
# INFO:tensorflow:step = 201, loss = 307.112 (0.588 sec)
# INFO:tensorflow:global_step/sec: 173.117
# INFO:tensorflow:step = 301, loss = 63.3027 (0.576 sec)
# INFO:tensorflow:global_step/sec: 173.117
# INFO:tensorflow:step = 401, loss = 178.754 (0.578 sec)
# INFO:tensorflow:global_step/sec: 171.927
# INFO:tensorflow:step = 501, loss = 417.028 (0.582 sec)
# INFO:tensorflow:global_step/sec: 170.754
# INFO:tensorflow:step = 601, loss = 45.3393 (0.588 sec)
# INFO:tensorflow:global_step/sec: 165.118
# INFO:tensorflow:step = 701, loss = 494.213 (0.605 sec)
# INFO:tensorflow:global_step/sec: 171.339
# INFO:tensorflow:step = 801, loss = 423.034 (0.584 sec)
# INFO:tensorflow:global_step/sec: 171.927
# INFO:tensorflow:step = 901, loss = 378.946 (0.582 sec)
# INFO:tensorflow:global_step/sec: 172.52
# INFO:tensorflow:step = 1001, loss = 46.1519 (0.581 sec)
# INFO:tensorflow:global_step/sec: 172.223
# INFO:tensorflow:step = 1101, loss = 115.75 (0.580 sec)
# INFO:tensorflow:global_step/sec: 138.782
# INFO:tensorflow:step = 1201, loss = 131.042 (0.727 sec)
# INFO:tensorflow:global_step/sec: 153.705
# INFO:tensorflow:step = 1301, loss = 42.8103 (0.645 sec)
# INFO:tensorflow:global_step/sec: 157.826
# INFO:tensorflow:step = 1401, loss = 485.798 (0.636 sec)
# INFO:tensorflow:global_step/sec: 167.888
# INFO:tensorflow:step = 1501, loss = 593.78 (0.594 sec)
# INFO:tensorflow:global_step/sec: 170.463
# INFO:tensorflow:step = 1601, loss = 33.6458 (0.587 sec)
# INFO:tensorflow:global_step/sec: 170.463
# INFO:tensorflow:step = 1701, loss = 132.059 (0.587 sec)
# INFO:tensorflow:global_step/sec: 162.174
# INFO:tensorflow:step = 1801, loss = 129.862 (0.618 sec)
# INFO:tensorflow:global_step/sec: 153.941
# INFO:tensorflow:step = 1901, loss = 85.9853 (0.649 sec)
# INFO:tensorflow:global_step/sec: 164.575
# INFO:tensorflow:step = 2001, loss = 75.7546 (0.608 sec)
# INFO:tensorflow:global_step/sec: 165.94
# INFO:tensorflow:step = 2101, loss = 236.085 (0.603 sec)
# INFO:tensorflow:global_step/sec: 159.588
# INFO:tensorflow:step = 2201, loss = 27.383 (0.624 sec)
# INFO:tensorflow:global_step/sec: 170.463
# INFO:tensorflow:step = 2301, loss = 62.7322 (0.591 sec)
# INFO:tensorflow:global_step/sec: 161.65
# INFO:tensorflow:step = 2401, loss = 77.6422 (0.618 sec)
# INFO:tensorflow:global_step/sec: 161.39
# INFO:tensorflow:step = 2501, loss = 84.2659 (0.619 sec)
# INFO:tensorflow:global_step/sec: 156.102
# INFO:tensorflow:step = 2601, loss = 31.3868 (0.642 sec)
# INFO:tensorflow:global_step/sec: 161.912
# INFO:tensorflow:step = 2701, loss = 27.7421 (0.617 sec)
# INFO:tensorflow:global_step/sec: 168.738
# INFO:tensorflow:step = 2801, loss = 118.51 (0.594 sec)
# INFO:tensorflow:global_step/sec: 141.33
# INFO:tensorflow:step = 2901, loss = 66.4779 (0.708 sec)
# INFO:tensorflow:global_step/sec: 171.632
# INFO:tensorflow:step = 3001, loss = 51.9617 (0.586 sec)
# INFO:tensorflow:global_step/sec: 158.325
# INFO:tensorflow:step = 3101, loss = 219.745 (0.629 sec)
# INFO:tensorflow:global_step/sec: 169.596
# INFO:tensorflow:step = 3201, loss = 41.7819 (0.592 sec)
# INFO:tensorflow:global_step/sec: 161.39
# INFO:tensorflow:step = 3301, loss = 26.317 (0.618 sec)
# INFO:tensorflow:global_step/sec: 154.655
# INFO:tensorflow:step = 3401, loss = 30.6086 (0.646 sec)
# INFO:tensorflow:global_step/sec: 171.338
# INFO:tensorflow:step = 3501, loss = 56.4589 (0.589 sec)
# INFO:tensorflow:global_step/sec: 172.52
# INFO:tensorflow:step = 3601, loss = 37.5442 (0.579 sec)
# INFO:tensorflow:global_step/sec: 171.338
# INFO:tensorflow:step = 3701, loss = 101.474 (0.581 sec)
# INFO:tensorflow:global_step/sec: 170.463
# INFO:tensorflow:step = 3801, loss = 31.2735 (0.588 sec)
# INFO:tensorflow:global_step/sec: 167.608
# INFO:tensorflow:step = 3901, loss = 89.7411 (0.596 sec)
# INFO:tensorflow:global_step/sec: 168.738
# INFO:tensorflow:step = 4001, loss = 89.8658 (0.593 sec)
# INFO:tensorflow:global_step/sec: 165.665
# INFO:tensorflow:step = 4101, loss = 259.233 (0.604 sec)
# INFO:tensorflow:global_step/sec: 156.591
# INFO:tensorflow:step = 4201, loss = 61.0358 (0.639 sec)
# INFO:tensorflow:global_step/sec: 169.309
# INFO:tensorflow:step = 4301, loss = 137.745 (0.591 sec)
# INFO:tensorflow:global_step/sec: 169.884
# INFO:tensorflow:step = 4401, loss = 32.7702 (0.589 sec)
# INFO:tensorflow:global_step/sec: 171.632
# INFO:tensorflow:step = 4501, loss = 54.5222 (0.582 sec)
# INFO:tensorflow:global_step/sec: 169.309
# INFO:tensorflow:step = 4601, loss = 37.573 (0.592 sec)
# INFO:tensorflow:global_step/sec: 158.075
# INFO:tensorflow:step = 4701, loss = 76.6321 (0.633 sec)
# INFO:tensorflow:global_step/sec: 171.045
# INFO:tensorflow:step = 4801, loss = 34.3622 (0.585 sec)
# INFO:tensorflow:global_step/sec: 167.888
# INFO:tensorflow:step = 4901, loss = 29.3676 (0.596 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Users\PERGO_~1\AppData\Local\Temp\tmp8cmlf2eg\model.ckpt.
# INFO:tensorflow:Loss for final step: 79.5526.
# INFO:tensorflow:Restoring parameters from C:\Users\PERGO_~1\AppData\Local\Temp\tmp8cmlf2eg\model.ckpt-5000
#              precision    recall  f1-score   support
#
#           0       0.88      0.90      0.89      7436
#           1       0.67      0.62      0.64      2333
#
# avg / total       0.83      0.84      0.83      9769
#
#
# accuracy_score:  0.835704780428
#
# [[6716  720]
#  [ 885 1448]]
